# %% [markdown]
# # 8.8- Veriyi hazırlamak

# %%
import pandas as pd # pip install pandas

dataFrame = pd.read_excel('bisiklet_fiyatlari.xlsx')

dataFrame.head()
# Out:
#         Fiyat  BisikletOzellik1  BisikletOzellik2
# 0  807.673876       1749.628226       1749.590668
# 1  959.227520       1748.007826       1751.824206
# 2  718.020033       1750.122967       1747.977026
# 3  945.668885       1749.916440       1750.771646
# 4  955.542968       1750.780519       1750.592430

# %%
import seaborn as sbn  # pip install seaborn
import matplotlib.pyplot as plt # pip install matplotlib

# %%
sbn.pairplot(dataFrame)

# %% [markdown]
# # 8.9-Test Bölmesi

# %%
# train_test_split

# %%
from sklearn.model_selection import train_test_split # pip install scikit-learn

#y = wx + b
# y -> label
y= dataFrame['Fiyat'].values

# x -> feature
x = dataFrame[['BisikletOzellik1', 'BisikletOzellik2']].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=15)

# %%
x_train.shape
# Out:
# (670, 2)

# %%
x_test.shape
# Out:
# (330, 2)

# %%
y_train.shape
# Out:
# (670,)

# %%
y_test.shape
# Out:
# (330,)

# %% [markdown]
# # 8.10 - Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[0.3177906 , 0.64341466],
#        [0.61991638, 0.89583174],
#        [0.53950097, 0.0980286 ],
#        ...,
#        [0.2352117 , 0.52644765],
#        [0.7576794 , 0.19157421],
#        [0.4292982 , 0.16530301]])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(5, activation='relu'))

model.add(Dense(1))
model.compile(optimizer='rmsprop', loss='mse')

# %%
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 778455.6875
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 801254.5000
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 810860.6250
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 792946.6250
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 801685.3125
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 790098.6250
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 772008.0000
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 777877.6250
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 773308.7500
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 779214.8125
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 797813.0000
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 807775.6875
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794512.1250
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 778696.6875
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 784670.2500
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 791616.6250
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794369.3750
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 776625.0000
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 771422.1875
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 776948.9375
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 762863.9375
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 775296.5000
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782022.7500
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 780018.4375
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 781091.1875
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 767514.3750
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 741231.5000
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 769514.0000
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 773436.7500
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 759111.6875
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 749124.8750
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 753651.5000
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 757327.5625
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 745077.0625
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 750929.1250
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 730399.8750
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 729135.5625
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 739620.7500
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 731301.3125
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 732109.6875
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 720889.6875
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 699398.3750
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 701330.9375
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 692463.7500
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 713197.0625
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675593.7500
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 683241.9375
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 665376.8750
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 667306.7500
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 650638.1250
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 651076.5625
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 637835.7500
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634611.0000
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 623468.1875
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 627998.3750
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 605539.1250
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 585184.6250
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593415.2500
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 571506.0625
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 569552.8125
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 563219.0000
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 541008.7500
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 538978.0000
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 523863.5938
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 498280.1875
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 492351.4062
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 483061.7188
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 472787.1562
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 443445.4062
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 445735.0000
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 428713.6875
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 408625.8125
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 409286.8750
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 390605.8750
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 367191.4688
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 355782.0312
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 337518.3438
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 331275.8438
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 306855.2812
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 297217.0000
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 281045.0938
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 261771.4219
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 251540.8281
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233442.5156
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 215613.4062
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 202964.8594
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 192005.9844
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 174022.2031
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 164454.0938
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 147195.9531
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 130488.9453
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123077.2344
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110273.2812
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92654.8672
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 77572.4141
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 73653.1953
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61649.3477
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51319.7070
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42701.2227
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33709.6992

# %%
loss = model.history.history["loss"]

# %%
sbn.lineplot(x=range(len(loss)), y=loss)
# Out:
# <Axes: >

# %%
trainLoss = model.evaluate(x_train, y_train,verbose=0)
trainLoss
# Out:
# 28934.78125

# %%
testLoss = model.evaluate(x_test, y_test,verbose=0)
testLoss
# Out:
# 1392232103936.0

# %%
testTahminleri = model.predict(x_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
testTahminleri
# Out:
# array([[1181797.4],
#        [1179912.2],
#        [1181030.6],
#        [1180526.6],
#        [1180453.1],
#        [1178241.4],
#        [1181056.1],
#        [1181216.9],
#        [1181628.2],
#        [1181479.4],
#        [1180502.8],
#        [1181474. ],
#        [1180839.9],
#        [1181783.6],
#        [1182416.6],
#        [1179913.2],
#        [1181566.8],
#        [1179344.4],
#        [1181609.9],
#        [1181049.4],
#        [1180957.6],
#        [1180600.9],
#        [1179560.4],
#        [1179208.6],
#        [1180964.6],
#        [1182062.9],
#        [1180049.5],
#        [1180212.2],
#        [1180600.5],
#        [1180304.2],
#        [1178785.8],
#        [1180727.4],
#        [1180189.1],
#        [1179643.6],
#        [1180825.1],
#        [1180672.8],
#        [1181702.2],
#        [1181187.6],
#        [1180910.9],
#        [1180658.1],
#        [1180447.5],
#        [1181916. ],
#        [1181870.4],
#        [1181905. ],
#        [1181392.1],
#        [1179713.9],
#        [1181497.6],
#        [1180994.4],
#        [1181359.9],
#        [1181027.2],
#        [1180363.1],
#        [1180546.2],
#        [1180361.8],
#        [1182090.4],
#        [1181065.1],
#        [1181511.8],
#        [1180654.2],
#        [1181135.9],
#        [1181259.1],
#        [1181350.5],
#        [1180345.4],
#        [1180727.4],
#        [1179613.9],
#        [1180460.9],
#        [1181450.6],
#        [1179781.6],
#        [1181059.4],
#        [1180383.6],
#        [1181023.8],
#        [1180573.9],
#        [1180315.5],
#        [1181065.5],
#        [1181673.1],
#        [1181254.6],
#        [1181640.6],
#        [1180073.6],
#        [1180005.5],
#        [1179849.8],
#        [1180812.4],
#        [1180603.1],
#        [1180970.4],
#        [1181323.4],
#        [1179623.4],
#        [1180730.8],
#        [1179390.9],
#        [1181675.9],
#        [1181191.4],
#        [1180978.9],
#        [1180495.4],
#        [1179984.6],
#        [1180903.1],
#        [1180042.8],
#        [1182450.5],
#        [1180909.8],
#        [1180815.9],
#        [1182081.8],
#        [1180901.5],
#        [1181217.1],
#        [1181087.9],
#        [1179001.4],
#        [1181725.8],
#        [1181652.5],
#        [1180677.2],
#        [1181661.8],
#        [1179414.5],
#        [1179670.2],
#        [1180933.5],
#        [1180405.4],
#        [1181328.2],
#        [1180759.5],
#        [1180167.6],
#        [1181400.5],
#        [1181236.6],
#        [1182194.1],
#        [1179536.4],
#        [1180721.8],
#        [1180672.4],
#        [1180687.6],
#        [1181372.1],
#        [1179910.5],
#        [1180370.8],
#        [1180423.8],
#        [1182087.9],
#        [1180018.6],
#        [1181253.6],
#        [1180980.4],
#        [1180821.9],
#        [1181142.1],
#        [1181613.6],
#        [1180827.2],
#        [1180409. ],
#        [1181709.4],
#        [1181843.6],
#        [1180642.2],
#        [1180062.1],
#        [1180364.4],
#        [1179982.6],
#        [1179983.9],
#        [1179990.2],
#        [1181692.9],
#        [1181184.4],
#        [1179994.2],
#        [1179451.2],
#        [1180247.5],
#        [1180584. ],
#        [1181235.8],
#        [1182539.4],
#        [1179488.8],
#        [1181566. ],
#        [1179842.1],
#        [1182199.6],
#        [1180618.9],
#        [1181963.6],
#        [1179966.8],
#        [1179889.1],
#        [1180069.5],
#        [1180837.9],
#        [1180903.9],
#        [1180328.1],
#        [1181725.4],
#        [1181858.9],
#        [1179826.2],
#        [1181436. ],
#        [1181820. ],
#        [1181197.9],
#        [1179793. ],
#        [1179201.9],
#        [1181627.9],
#        [1180201. ],
#        [1180624.5],
#        [1182340.2],
#        [1180074.2]], dtype=float32)

# %%
tahminDf = pd.DataFrame(y_test, columns=['Gerçek Y'])

# %%
tahminDf
# Out:
#         Gerçek Y
# 0    1081.652164
# 1     622.675990
# 2     889.356810
# 3     902.826733
# 4     897.662404
# ..           ...
# 325  1028.438035
# 326   789.934950
# 327   758.490486
# 328  1172.871659
# 329   820.947936
#
# [330 rows x 1 columns]

# %%
testTahminleri = pd.Series(testTahminleri.reshape(330,))

# %%
testTahminleri
# Out:
# 0      1181797.375
# 1      1179912.250
# 2      1181030.625
# 3      1180526.625
# 4      1180453.125
#           ...
# 325    1181627.875
# 326    1180201.000
# 327    1180624.500
# 328    1182340.250
# 329    1180074.250
# Length: 330, dtype: float32

# %%
tahminDf = pd.concat([tahminDf, testTahminleri], axis=1)

# %%
tahminDf
# Out:
#         Gerçek Y            0
# 0    1081.652164  1181797.375
# 1     622.675990  1179912.250
# 2     889.356810  1181030.625
# 3     902.826733  1180526.625
# 4     897.662404  1180453.125
# ..           ...          ...
# 325  1028.438035  1181627.875
# 326   789.934950  1180201.000
# 327   758.490486  1180624.500
# 328  1172.871659  1182340.250
# 329   820.947936  1180074.250
#
# [330 rows x 2 columns]

# %%
tahminDf.columns = ['Gerçek Y', 'Tahmin Y']

# %%
tahminDf
# Out:
#         Gerçek Y     Tahmin Y
# 0    1081.652164  1181797.375
# 1     622.675990  1179912.250
# 2     889.356810  1181030.625
# 3     902.826733  1180526.625
# 4     897.662404  1180453.125
# ..           ...          ...
# 325  1028.438035  1181627.875
# 326   789.934950  1180201.000
# 327   758.490486  1180624.500
# 328  1172.871659  1182340.250
# 329   820.947936  1180074.250
#
# [330 rows x 2 columns]

# %%
sbn.scatterplot(x='Gerçek Y', y='Tahmin Y', data=tahminDf)
# Out:
# <Axes: xlabel='Gerçek Y', ylabel='Tahmin Y'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(tahminDf['Gerçek Y'], tahminDf['Tahmin Y'])
# Out:
# 1179928.6493409013

# %% [markdown]
# # 8.13 - Model Tahminleri

# %%
yeniBisikletOzellikleri = [[1760, 1758]]

# %%
yeniBisikletOzellikleri = scaler.transform(yeniBisikletOzellikleri)

# %%
model.predict(yeniBisikletOzellikleri)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# array([[1186954.]], dtype=float32)

# %%
from tensorflow.keras.models import load_model

# %%
model.save('bisiklet_modeli.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.losses import MeanSquaredError

# Load the model with custom objects
sonradan = load_model('bisiklet_modeli.h5', custom_objects={'mse': MeanSquaredError()})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
sonradan.predict(yeniBisikletOzellikleri)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# array([[1186954.]], dtype=float32)
